# %%
import pandas as pd
import numpy as np

# %%
hof_df = pd.read_csv("snubs.csv")
# hof_df.drop(hof_df.loc[hof_df["Years Waited"]=="*"].index, inplace=True)
# hof_df.drop(columns=["Inducted By"], inplace=True)
hof_df.head()
# Out:
#              Artist  Year Inducted  Years Waited  # of Years Nominated
# 0  Afrika Bambaataa            NaN            14                     1
# 1   Alice In Chains            NaN             3                     0
# 2        Bad Brains            NaN            12                     1
# 3       Bad Company            NaN            20                     0
# 4       Barry White            NaN            21                     0

# %%
infl_df = pd.read_csv("The 100 most influential artists, according to AllMusic data.csv")
infl_df = infl_df.rename(columns={"artistname" : "Artist", "artists influenced" : "Influenced"})
infl_df.head()
# Out:
#                  Artist  Influenced
# 0                  2Pac          39
# 1  A Tribe Called Quest          26
# 2                  ABBA          19
# 3                 AC/DC         121
# 4             Aerosmith          24

# %%
rnr_df = pd.merge(hof_df, infl_df, on="Artist", how="left")
rnr_df = rnr_df.sort_values(by=["Influenced"])
rnr_df.head()
# Out:
#                           Artist  Year Inducted  Years Waited  \
# 125      The Sir Douglas Quintet            NaN            25
# 38                   Guitar Slim            NaN            42
# 22                  Chuck Willis            NaN            42
# 107                 The Chantels            NaN            35
# 132  Tommy James & the Shondells            NaN            28
#
#      # of Years Nominated  Influenced
# 125                     1           0
# 38                      0           0
# 22                      6           0
# 107                     2           0
# 132                     0           0

# %%
uss_df = pd.read_csv("Album sales US.csv")
rnr_df = pd.merge(rnr_df, uss_df, on="Artist", how="left")
rnr_df.head()
# Out:
#                         Artist  Year Inducted  Years Waited  \
# 0      The Sir Douglas Quintet            NaN            25
# 1                  Guitar Slim            NaN            42
# 2                 Chuck Willis            NaN            42
# 3                 The Chantels            NaN            35
# 4  Tommy James & the Shondells            NaN            28
#
#    # of Years Nominated  Influenced  Certified Units (Millions)
# 0                     1           0                         0.0
# 1                     0           0                         0.0
# 2                     6           0                         0.0
# 3                     2           0                         0.0
# 4                     0           0                         0.0

# %%
rnr_df = rnr_df.sort_values(by=["Certified Units (Millions)"], ascending = False)
rsa_df = pd.read_csv("RS500.csv")
rnr_df = pd.merge(rnr_df, rsa_df, on="Artist", how="left")
rnr_df
# Out:
#                           Artist  Year Inducted  Years Waited  \
# 0                Whitney Houston            NaN            10
# 1                      Foreigner            NaN            16
# 2                   Phil Collins            NaN            12
# 3                  Willie Nelson            NaN            32
# 4                         Boston            NaN            17
# 5                  Ozzy Osbourne            NaN            14
# 6                    Motley Crue            NaN            13
# 7                 The Carpenters            NaN            25
# 8            The Doobie Brothers            NaN            23
# 9              Smashing Pumpkins            NaN             3
# 10                         Sting            NaN            11
# 11                   The Monkees            NaN            28
# 12                          Styx            NaN            21
# 13           Stone Temple Pilots            NaN             1
# 14                   Bad Company            NaN            20
# 15                        Kansas            NaN            19
# 16                George Michael            NaN             7
# 17                          INXS            NaN            14
# 18                   Carole King            NaN            35
# 19               Alice In Chains            NaN             3
# 20                          Cher            NaN            28
# 21                   Pat Benatar            NaN            15
# 22                   Duran Duran            NaN            13
# 23                   Jethro Tull            NaN            26
# 24                   Barry White            NaN            21
# 25                     Scorpions            NaN            21
# 26               Nine Inch Nails            NaN             5
# 27                  Depeche Mode            NaN            13
# 28                Peter Frampton            NaN            21
# 29                   Tina Turner            NaN            20
# ..                           ...            ...           ...
# 115              The Marvelettes            NaN            33
# 116              Esther Phillips            NaN            43
# 117  Billy Ward and his Dominoes            NaN            43
# 118              Johnny Burnette            NaN            38
# 119  Tommy James & the Shondells            NaN            28
# 120                 The Chantels            NaN            35
# 121                 Chuck Willis            NaN            42
# 122                  Ben E. King            NaN            32
# 123                    Link Wray            NaN            36
# 124                    Motorhead            NaN            17
# 125                   The Meters            NaN            24
# 126                   Bad Brains            NaN            12
# 127                 Scott Walker            NaN            28
# 128      Siouxsie & the Banshees            NaN            16
# 129                         Love            NaN            28
# 130                Silver Apples            NaN            26
# 131                   The J.B.'s            NaN            23
# 132                 The Runaways            NaN            18
# 133        Screamin' Jay Hawkins            NaN            36
# 134                 The Specials            NaN            15
# 135                  Guitar Slim            NaN            42
# 136             Afrika Bambaataa            NaN            14
# 137                   Television            NaN            19
# 138                    Dick Dale            NaN            32
# 139                       Sparks            NaN            23
# 140          Toots & the Maytals            NaN            32
# 141                    Brian Eno            NaN            20
# 142         A Tribe Called Quest            NaN             3
# 143                    Husker Du            NaN            13
# 144                     Pavement            NaN             4
#
#      # of Years Nominated  Influenced  Certified Units (Millions)  \
# 0                       0          35                       58.50
# 1                       0          10                       37.50
# 2                       0          10                       33.50
# 3                       0          19                       31.50
# 4                       0          13                       31.00
# 5                       0          14                       27.25
# 6                       0          15                       25.00
# 7                       0          10                       24.50
# 8                       0          10                       22.00
# 9                       0          15                       19.75
# 10                      1          16                       18.00
# 11                      0          11                       18.00
# 12                      0          13                       17.50
# 13                      0           6                       17.50
# 14                      0          15                       15.50
# 15                      0          10                       15.50
# 16                      0          19                       15.00
# 17                      0          15                       15.00
# 18                      1          23                       14.50
# 19                      0          19                       12.50
# 20                      0           7                       12.50
# 21                      0          11                       12.50
# 22                      0          22                       12.00
# 23                      0          15                       11.00
# 24                      0          13                       11.00
# 25                      0          10                       10.50
# 26                      2          30                       10.50
# 27                      2         120                       10.50
# 28                      0           6                       10.00
# 29                      0          19                       10.00
# ..                    ...         ...                         ...
# 115                     2           5                        0.00
# 116                     2           3                        0.00
# 117                     1           0                        0.00
# 118                     0           0                        0.00
# 119                     0           0                        0.00
# 120                     2           0                        0.00
# 121                     6           0                        0.00
# 122                     3          13                        0.00
# 123                     2          14                        0.00
# 124                     0          20                        0.00
# 125                     4          14                        0.00
# 126                     1          18                        0.00
# 127                     0          18                        0.00
# 128                     0          17                        0.00
# 129                     0          16                        0.00
# 130                     0          16                        0.00
# 131                     1          16                        0.00
# 132                     0          16                        0.00
# 133                     0          16                        0.00
# 134                     0          15                        0.00
# 135                     0           0                        0.00
# 136                     1          15                        0.00
# 137                     0          15                        0.00
# 138                     0          15                        0.00
# 139                     0          15                        0.00
# 140                     0          14                        0.00
# 141                     0         327                        0.00
# 142                     0          26                         NaN
# 143                     0          45                         NaN
# 144                     0          49                         NaN
#
#      Albums in RS500
# 0                1.0
# 1                NaN
# 2                NaN
# 3                2.0
# 4                NaN
# 5                NaN
# 6                NaN
# 7                1.0
# 8                NaN
# 9                1.0
# 10               NaN
# 11               NaN
# 12               NaN
# 13               NaN
# 14               NaN
# 15               NaN
# 16               1.0
# 17               NaN
# 18               1.0
# 19               NaN
# 20               NaN
# 21               NaN
# 22               NaN
# 23               1.0
# 24               1.0
# 25               NaN
# 26               1.0
# 27               1.0
# 28               NaN
# 29               NaN
# ..               ...
# 115              NaN
# 116              NaN
# 117              NaN
# 118              NaN
# 119              NaN
# 120              NaN
# 121              NaN
# 122              NaN
# 123              NaN
# 124              NaN
# 125              2.0
# 126              NaN
# 127              NaN
# 128              NaN
# 129              1.0
# 130              NaN
# 131              NaN
# 132              NaN
# 133              NaN
# 134              NaN
# 135              NaN
# 136              NaN
# 137              1.0
# 138              NaN
# 139              NaN
# 140              1.0
# 141              2.0
# 142              1.0
# 143              1.0
# 144              2.0
#
# [145 rows x 7 columns]

# %%
hot_df = pd.read_csv("hot100singles.csv")
hot_df = hot_df.rename(columns={"Row Labels" : "Artist"})
rnr_df = pd.merge(rnr_df, hot_df, on="Artist", how="left")
rnr_df.head()
# Out:
#             Artist  Year Inducted  Years Waited  # of Years Nominated  \
# 0  Whitney Houston            NaN            10                     0
# 1        Foreigner            NaN            16                     0
# 2     Phil Collins            NaN            12                     0
# 3    Willie Nelson            NaN            32                     0
# 4           Boston            NaN            17                     0
#
#    Influenced  Certified Units (Millions)  Albums in RS500  Top 100 Singles  \
# 0          35                        58.5              1.0             44.0
# 1          10                        37.5              NaN             22.0
# 2          10                        33.5              NaN             27.0
# 3          19                        31.5              2.0             10.0
# 4          13                        31.0              NaN             10.0
#
#    Highest Position
# 0               1.0
# 1               1.0
# 2               1.0
# 3               5.0
# 4               1.0

# %%
rsc_df = pd.read_csv("RSCovers.csv")
rnr_df = pd.merge(rnr_df, rsc_df, on="Artist", how="left")

# %%
abs_df = pd.read_csv("Album_scores.csv")
rnr_df = pd.merge(rnr_df, abs_df, on="Artist", how="left")
rnr_df.head()
# Out:
#             Artist  Year Inducted  Years Waited  # of Years Nominated  \
# 0  Whitney Houston            NaN            10                     0
# 1        Foreigner            NaN            16                     0
# 2     Phil Collins            NaN            12                     0
# 3    Willie Nelson            NaN            32                     0
# 4           Boston            NaN            17                     0
#
#    Influenced  Certified Units (Millions)  Albums in RS500  Top 100 Singles  \
# 0          35                        58.5              1.0             44.0
# 1          10                        37.5              NaN             22.0
# 2          10                        33.5              NaN             27.0
# 3          19                        31.5              2.0             10.0
# 4          13                        31.0              NaN             10.0
#
#    Highest Position  Times on Cover of RS  Score
# 0               1.0                   2.0   3.34
# 1               1.0                   NaN   3.33
# 2               1.0                   2.0   3.69
# 3               5.0                   1.0   3.37
# 4               1.0                   NaN   3.17

# %%
rnr_df.to_csv("output/snubbed.csv")
