# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
sns.pairplot(hall,hue='In_Out',palette='Set1')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-09f8d85eccb4> in <module>()
# ----> 1 sns.pairplot(hall,hue='In_Out',palette='Set1')
#
# NameError: name 'hall' is not defined

# %%
#### these result are only to 1 DECIMAL place
from sklearn.ensemble import RandomForestClassifier
classify = RandomForestClassifier()
classify.fit(X_train,y_train)
induct_prob = classify.predict_proba(induct)
ip = pd.DataFrame(induct_prob)
ip
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a1d078f977ad> in <module>()
#       2 from sklearn.ensemble import RandomForestClassifier
#       3 classify = RandomForestClassifier()
# ----> 4 classify.fit(X_train,y_train)
#       5 induct_prob = classify.predict_proba(induct)
#       6 ip = pd.DataFrame(induct_prob)
#
# NameError: name 'X_train' is not defined

# %%
induct = pd.read_csv('Rock_Hall/output/2019.csv')
induct.drop(['Unnamed: 0',  'Years Waited', 'Year Inducted','In_Out','Artist','Highest Position','# of Years Nominated' ], axis=1, inplace=True)
induct
# Out:
#     Influenced  Certified Units (Millions)  Albums in RS500  Top 100 Singles  \
# 0           20                        35.5              1.0               19
# 1           26                        26.0              2.0               36
# 2           14                        12.5              1.0               26
# 3           17                        10.5              0.0               14
# 4           36                         9.0              1.0                1
# 5          193                         8.5              2.0               14
# 6          163                         6.5              5.0                3
# 7            8                         3.5              0.0               12
# 8           26                         1.5              1.0                3
# 9          160                         1.0              2.0                3
# 10          18                         0.5              1.0               14
# 11          21                         0.5              1.0                0
# 12          72                         0.0              1.0                5
# 13         160                         0.0              2.0                1
# 14         323                         0.0              1.0                2
#
#     Times on Cover of RS  Score  Spotify
# 0                    1.0   3.68  3415682
# 1                    3.0   3.23  4248668
# 2                    1.0   3.23  2009491
# 3                    2.0   3.57  1980117
# 4                    3.0   4.13  4945499
# 5                    0.0   3.31  5962466
# 6                    5.0   4.17  8304956
# 7                    0.0   3.38  7806261
# 8                    0.0   3.06  1096660
# 9                    1.0   4.17  1181065
# 10                   0.0   3.25   741455
# 11                   0.0   3.58   916496
# 12                   0.0   3.90  1418069
# 13                   0.0   4.50   158341
# 14                   0.0   4.05   632119

# %%
future = pd.read_csv('Rock_Hall/output/2044.csv')
future.drop(['Unnamed: 0',  'Years Waited', 'Year Inducted','In_Out','Highest Position','# of Years Nominated','Artist' ], axis=1, inplace=True)
future
# Out:
#     Influenced  Certified Units (Millions)  Albums in RS500  Top 100 Singles  \
# 0           35                        45.0              2.0               39
# 1            2                        43.0              0.0               63
# 2            8                        28.0              0.0                7
# 3           14                        22.5              0.0               38
# 4           21                        17.5              0.0               35
# 5           43                        14.5              3.0               38
# 6           45                        14.5              1.0               15
# 7           10                        13.5              0.0               41
# 8           12                        13.0              0.0               30
# 9            5                        12.5              0.0               14
# 10           9                        11.0              0.0               11
# 11          27                        10.5              1.0               41
# 12          28                        10.5              0.0               16
# 13           9                        10.0              0.0                2
# 14           5                         8.5              0.0                0
# 15          10                         7.5              0.0                5
# 16           7                         7.5              0.0               17
# 17           8                         7.0              0.0                1
# 18           1                         5.0              0.0                4
# 19           1                         4.0              0.0                5
# 20           0                         4.0              0.0                0
# 21           0                         2.5              0.0                0
# 22           0                         2.0              0.0                0
# 23           1                         1.5              0.0               11
# 24           3                         0.5              0.0                4
#
#     Times on Cover of RS  Score   Spotify
# 0                   10.0   3.64  37005375
# 1                    2.0   3.83  21574771
# 2                    3.0   3.88  18457272
# 3                    2.0   3.69  29844278
# 4                    0.0   3.19  49250750
# 5                    2.0   3.90  38982857
# 6                    2.0   3.86  26840941
# 7                    3.0   3.21  26991314
# 8                    2.0   3.75  25342254
# 9                    1.0   3.75  38295819
# 10                   2.0   3.17  32374113
# 11                   2.0   3.29  28914305
# 12                   5.0   2.70  18876839
# 13                   1.0   3.33  38515476
# 14                   2.0   3.79  25608153
# 15                   2.0   4.40  25049809
# 16                   1.0   3.50  31614136
# 17                   1.0   2.92  24771994
# 18                   0.0   3.17  38776996
# 19                   0.0   3.88  32914730
# 20                   0.0   3.88  17229601
# 21                   0.0   2.00  33194973
# 22                   1.0   4.00  27980698
# 23                   0.0   3.30  23355145
# 24                   0.0   3.60  42001546

# %%
hall = pd.read_csv('Rock_Hall/output/artist_data.csv')
hall.head()
hall.drop(['Unnamed: 0', 'Years Waited', 'Year Inducted', 'Artist',  '# of Years Nominated', 'Highest Position'], axis=1, inplace=True)

hall.head()
# Out:
#    Influenced  Certified Units (Millions)  Albums in RS500  Top 100 Singles  \
# 0        1230                       178.0               10               80
# 1         273                       146.5                3              158
# 2          17                       120.0                2               21
# 3         355                       111.5                5               10
# 4         176                        84.0                3               49
#
#    Times on Cover of RS  Score   Spotify  In_Out
# 0                    16   4.81  15022354       1
# 1                     7   3.31   7518562       1
# 2                     3   3.50   8989332       1
# 3                    12   4.50  10306295       1
# 4                     6   3.65  24068900       1

# %%
from sklearn.model_selection import train_test_split

X = hall.drop('In_Out', axis =1)
y = hall['In_Out']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
X_test.columns
# Out:
# Index(['Influenced', 'Certified Units (Millions)', 'Albums in RS500',
#        'Top 100 Singles', 'Times on Cover of RS', 'Score', 'Spotify'],
#       dtype='object')

# %%
from sklearn.ensemble import RandomForestClassifier
classify = RandomForestClassifier(n_estimators=500)
classify.fit(X_train,y_train)
#(classify.predict_proba(X_test))
fclass = classify.predict_proba(future)
fclass1 = pd.DataFrame(fclass)
fclass1
# Out:
#         0      1
# 0   0.038  0.962
# 1   0.632  0.368
# 2   0.642  0.358
# 3   0.266  0.734
# 4   0.154  0.846
# 5   0.088  0.912
# 6   0.414  0.586
# 7   0.564  0.436
# 8   0.430  0.570
# 9   0.734  0.266
# 10  0.748  0.252
# 11  0.314  0.686
# 12  0.716  0.284
# 13  0.720  0.280
# 14  0.772  0.228
# 15  0.710  0.290
# 16  0.698  0.302
# 17  0.712  0.288
# 18  0.582  0.418
# 19  0.610  0.390
# 20  0.682  0.318
# 21  0.634  0.366
# 22  0.656  0.344
# 23  0.492  0.508
# 24  0.744  0.256

# %%
future2 = pd.read_csv('Rock_Hall/output/2044.csv')
future1 = future2['Artist']
#induct1 = induct1.iloc[::-1]
df = pd.DataFrame(data=future1)
df.reset_index(inplace=True)
classof2044 = pd.concat([df,fclass1], axis=1)
classof2044.columns
classof2044.drop(['index',0], axis=1)
# Out:
#                Artist      1
# 0              Eminem  0.962
# 1        Taylor Swift  0.368
# 2               Adele  0.358
# 3             Rihanna  0.734
# 4               Drake  0.846
# 5          Kanye West  0.912
# 6            Coldplay  0.586
# 7       Justin Bieber  0.436
# 8             Beyonce  0.570
# 9            Maroon 5  0.266
# 10         Bruno Mars  0.252
# 11          Lil Wayne  0.686
# 12  Justin Timberlake  0.284
# 13         Ed Sheeran  0.280
# 14          Lady Gaga  0.228
# 15     Kendrick Lamar  0.290
# 16        Nicki Minaj  0.302
# 17         The Weeknd  0.288
# 18    Imagine Dragons  0.418
# 19      Ariana Grande  0.390
# 20  Twenty-One Pilots  0.318
# 21   The Chainsmokers  0.366
# 22            Cardi B  0.344
# 23          DJ Khaled  0.508
# 24      Calvin Harris  0.256

# %%
from sklearn.ensemble import RandomForestClassifier
classify = RandomForestClassifier(n_estimators=500)
classify.fit(X_train,y_train)
#(classify.predict_proba(X_test))
decimals = classify.predict_proba(induct)
decimals = pd.DataFrame(decimals)
decimals
# Out:
#         0      1
# 0   0.122  0.878
# 1   0.040  0.960
# 2   0.408  0.592
# 3   0.556  0.444
# 4   0.536  0.464
# 5   0.142  0.858
# 6   0.050  0.950
# 7   0.680  0.320
# 8   0.472  0.528
# 9   0.232  0.768
# 10  0.090  0.910
# 11  0.778  0.222
# 12  0.582  0.418
# 13  0.786  0.214
# 14  0.600  0.400

# %%
induct2 = pd.read_csv('Rock_Hall/output/2019.csv')
induct1 = induct2['Artist']
#induct1 = induct1.iloc[::-1]
df = pd.DataFrame(data=induct1)
df.reset_index(inplace=True)
classof2019 = pd.concat([df,decimals], axis=1)
classof2019.columns
classof2019.drop(['index',0], axis=1)
# Out:
#                         Artist      1
# 0                  Def Leppard  0.878
# 1                Janet Jackson  0.960
# 2                    LL Cool J  0.592
# 3                 Stevie Nicks  0.444
# 4     Rage Against the Machine  0.464
# 5                     The Cure  0.858
# 6                    Radiohead  0.950
# 7   Rufus featuring Chaka Khan  0.320
# 8                         Devo  0.528
# 9                   Roxy Music  0.768
# 10               Todd Rundgren  0.910
# 11                  John Prine  0.222
# 12                 The Zombies  0.418
# 13                         MC5  0.214
# 14                   Kraftwerk  0.400

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier()
dtree.fit(X_train,y_train)
predictions = dtree.predict(X_test)
from sklearn.metrics import classification_report,confusion_matrix
from sklearn import metrics

print(classification_report(y_test,predictions))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.62      0.73      0.67        41
#           1       0.82      0.73      0.77        67
#
# avg / total       0.74      0.73      0.73       108

# %%
from sklearn.ensemble import RandomForestClassifier
classify = RandomForestClassifier(n_estimators=500)
classify.fit(X_train,y_train)
#(classify.predict_proba(X_test))
print(classify.predict_proba(induct))
print(confusion_matrix(y_test,predictions))
# Out:
# [[0.15  0.85 ]
#  [0.038 0.962]
#  [0.466 0.534]
#  [0.554 0.446]
#  [0.554 0.446]
#  [0.136 0.864]
#  [0.066 0.934]
#  [0.69  0.31 ]
#  [0.448 0.552]
#  [0.26  0.74 ]
#  [0.082 0.918]
#  [0.766 0.234]
#  [0.558 0.442]
#  [0.816 0.184]
#  [0.604 0.396]]
# [[30 11]
#  [18 49]]

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=600)
rfc.fit(X_train,y_train)
predictions = rfc.predict(X_test)
print(classification_report(y_test,predictions))
print(confusion_matrix(y_test,predictions))
list(zip(hall.columns, rfc.feature_importances_))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.69      0.76      0.72        41
#           1       0.84      0.79      0.82        67
#
# avg / total       0.78      0.78      0.78       108
#
# [[31 10]
#  [14 53]]
# [('Influenced', 0.15241681775229463),
#  ('Certified Units (Millions)', 0.13764901840161703),
#  ('Albums in RS500', 0.09715436105884098),
#  ('Top 100 Singles', 0.23499118280795434),
#  ('Times on Cover of RS', 0.0533365645512242),
#  ('Score', 0.16292665684583188),
#  ('Spotify', 0.1615253985822371)]

# %%
from IPython.display import Image  
from sklearn.externals.six import StringIO  
from sklearn.tree import export_graphviz
import pydot 

features = list(induct.columns)
features
# Out:
# ['Influenced',
#  'Certified Units (Millions)',
#  'Albums in RS500',
#  'Top 100 Singles',
#  'Times on Cover of RS',
#  'Score',
#  'Spotify']

# %%
dot_data = StringIO()  
export_graphviz(dtree, out_file=dot_data,feature_names=features,filled=True,rounded=True)

graph = pydot.graph_from_dot_data(dot_data.getvalue())  
Image(graph[0].create_png())

# %%
df = pd.read_csv('Rock_Hall/output/artist_data.csv')
test1 = df.groupby(['# of Years Nominated', 'In_Out']).groups
print(test1)
