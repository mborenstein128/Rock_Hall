# %%
import pandas as pd
import numpy as np

# %%
hof3_df = pd.read_csv("nominees_2019.csv")
# hof3_df.drop(hof3_df.loc[hof3_df["Years Waited"]=="*"].index, inplace=True)
# hof3_df.drop(columns=["Inducted By"], inplace=True)
hof3_df.head()
# Out:
#           Artist  Year Inducted  Years Waited  # of Years Nominated
# 0    Def Leppard            NaN            13                     1
# 1           Devo            NaN            15                     1
# 2  Janet Jackson            NaN            11                     3
# 3     John Prine            NaN            22                     1
# 4      Kraftwerk            NaN            23                     5

# %%
infl_df = pd.read_csv("The 100 most influential artists, according to AllMusic data.csv")
infl_df = infl_df.rename(columns={"artistname" : "Artist", "artists influenced" : "Influenced"})
infl_df.head()
# Out:
#                  Artist  Influenced
# 0                  2Pac          39
# 1  A Tribe Called Quest          26
# 2                  ABBA          19
# 3                 AC/DC         121
# 4             Aerosmith          24

# %%
rnr_df = pd.merge(hof3_df, infl_df, on="Artist", how="left")
rnr_df = rnr_df.sort_values(by=["Influenced"])
rnr_df.head()
# Out:
#                         Artist  Year Inducted  Years Waited  \
# 10  Rufus featuring Chaka Khan            NaN            19
# 5                    LL Cool J            NaN             9
# 11                Stevie Nicks            NaN            12
# 14               Todd Rundgren            NaN            23
# 0                  Def Leppard            NaN            13
#
#     # of Years Nominated  Influenced
# 10                     3           8
# 5                      5          14
# 11                     1          17
# 14                     1          18
# 0                      1          20

# %%
uss_df = pd.read_csv("Album sales US.csv")
rnr_df = pd.merge(rnr_df, uss_df, on="Artist", how="left")
rnr_df.head()
# Out:
#                        Artist  Year Inducted  Years Waited  \
# 0  Rufus featuring Chaka Khan            NaN            19
# 1                   LL Cool J            NaN             9
# 2                Stevie Nicks            NaN            12
# 3               Todd Rundgren            NaN            23
# 4                 Def Leppard            NaN            13
#
#    # of Years Nominated  Influenced  Certified Units (Millions)
# 0                     3           8                         3.5
# 1                     5          14                        12.5
# 2                     1          17                        10.5
# 3                     1          18                         0.5
# 4                     1          20                        35.5

# %%
rnr_df = rnr_df.sort_values(by=["Certified Units (Millions)"], ascending = False)
rsa_df = pd.read_csv("RS500.csv")
rnr_df = pd.merge(rnr_df, rsa_df, on="Artist", how="left")
rnr_df
# Out:
#                         Artist  Year Inducted  Years Waited  \
# 0                  Def Leppard            NaN            13
# 1                Janet Jackson            NaN            11
# 2                    LL Cool J            NaN             9
# 3                 Stevie Nicks            NaN            12
# 4     Rage Against the Machine            NaN             1
# 5                     The Cure            NaN            14
# 6                    Radiohead            NaN             1
# 7   Rufus featuring Chaka Khan            NaN            19
# 8                         Devo            NaN            15
# 9                   Roxy Music            NaN            21
# 10               Todd Rundgren            NaN            23
# 11                  John Prine            NaN            22
# 12                 The Zombies            NaN            29
# 13                         MC5            NaN            27
# 14                   Kraftwerk            NaN            23
#
#     # of Years Nominated  Influenced  Certified Units (Millions)  \
# 0                      1          20                        35.5
# 1                      3          26                        26.0
# 2                      5          14                        12.5
# 3                      1          17                        10.5
# 4                      2          36                         9.0
# 5                      2         193                         8.5
# 6                      2         163                         6.5
# 7                      3           8                         3.5
# 8                      1          26                         1.5
# 9                      1         160                         1.0
# 10                     1          18                         0.5
# 11                     1          21                         0.5
# 12                     4          72                         0.0
# 13                     4         160                         0.0
# 14                     5         323                         0.0
#
#     Albums in RS500
# 0               1.0
# 1               2.0
# 2               1.0
# 3               NaN
# 4               1.0
# 5               2.0
# 6               5.0
# 7               NaN
# 8               1.0
# 9               2.0
# 10              1.0
# 11              1.0
# 12              1.0
# 13              2.0
# 14              1.0

# %%
hot_df = pd.read_csv("hot100singles.csv")
hot_df = hot_df.rename(columns={"Row Labels" : "Artist"})
rnr_df = pd.merge(rnr_df, hot_df, on="Artist", how="left")
rnr_df.head()
# Out:
#                      Artist  Year Inducted  Years Waited  \
# 0               Def Leppard            NaN            13
# 1             Janet Jackson            NaN            11
# 2                 LL Cool J            NaN             9
# 3              Stevie Nicks            NaN            12
# 4  Rage Against the Machine            NaN             1
#
#    # of Years Nominated  Influenced  Certified Units (Millions)  \
# 0                     1          20                        35.5
# 1                     3          26                        26.0
# 2                     5          14                        12.5
# 3                     1          17                        10.5
# 4                     2          36                         9.0
#
#    Albums in RS500  Top 100 Singles  Highest Position
# 0              1.0             19.0               1.0
# 1              2.0             36.0               1.0
# 2              1.0             26.0               3.0
# 3              NaN             14.0               3.0
# 4              1.0              1.0              69.0

# %%
rsc_df = pd.read_csv("RSCovers.csv")
rnr_df = pd.merge(rnr_df, rsc_df, on="Artist", how="left")

# %%
abs_df = pd.read_csv("Album_scores.csv")
rnr_df = pd.merge(rnr_df, abs_df, on="Artist", how="left")
rnr_df.head()
# Out:
#                      Artist  Year Inducted  Years Waited  \
# 0               Def Leppard            NaN            13
# 1             Janet Jackson            NaN            11
# 2                 LL Cool J            NaN             9
# 3              Stevie Nicks            NaN            12
# 4  Rage Against the Machine            NaN             1
#
#    # of Years Nominated  Influenced  Certified Units (Millions)  \
# 0                     1          20                        35.5
# 1                     3          26                        26.0
# 2                     5          14                        12.5
# 3                     1          17                        10.5
# 4                     2          36                         9.0
#
#    Albums in RS500  Top 100 Singles  Highest Position  Times on Cover of RS  \
# 0              1.0             19.0               1.0                   1.0
# 1              2.0             36.0               1.0                   3.0
# 2              1.0             26.0               3.0                   1.0
# 3              NaN             14.0               3.0                   2.0
# 4              1.0              1.0              69.0                   3.0
#
#    Score
# 0   3.68
# 1   3.23
# 2   3.23
# 3   3.57
# 4   4.13

# %%
rnr_df.fillna(0, inplace=True)
rnr_df
# Out:
#                         Artist  Year Inducted  Years Waited  \
# 0                  Def Leppard            0.0            13
# 1                Janet Jackson            0.0            11
# 2                    LL Cool J            0.0             9
# 3                 Stevie Nicks            0.0            12
# 4     Rage Against the Machine            0.0             1
# 5                     The Cure            0.0            14
# 6                    Radiohead            0.0             1
# 7   Rufus featuring Chaka Khan            0.0            19
# 8                         Devo            0.0            15
# 9                   Roxy Music            0.0            21
# 10               Todd Rundgren            0.0            23
# 11                  John Prine            0.0            22
# 12                 The Zombies            0.0            29
# 13                         MC5            0.0            27
# 14                   Kraftwerk            0.0            23
#
#     # of Years Nominated  Influenced  Certified Units (Millions)  \
# 0                      1          20                        35.5
# 1                      3          26                        26.0
# 2                      5          14                        12.5
# 3                      1          17                        10.5
# 4                      2          36                         9.0
# 5                      2         193                         8.5
# 6                      2         163                         6.5
# 7                      3           8                         3.5
# 8                      1          26                         1.5
# 9                      1         160                         1.0
# 10                     1          18                         0.5
# 11                     1          21                         0.5
# 12                     4          72                         0.0
# 13                     4         160                         0.0
# 14                     5         323                         0.0
#
#     Albums in RS500  Top 100 Singles  Highest Position  Times on Cover of RS  \
# 0               1.0             19.0               1.0                   1.0
# 1               2.0             36.0               1.0                   3.0
# 2               1.0             26.0               3.0                   1.0
# 3               0.0             14.0               3.0                   2.0
# 4               1.0              1.0              69.0                   3.0
# 5               2.0             14.0               2.0                   0.0
# 6               5.0              3.0              34.0                   5.0
# 7               0.0             12.0               3.0                   0.0
# 8               1.0              3.0              14.0                   0.0
# 9               2.0              3.0              30.0                   1.0
# 10              1.0             14.0               5.0                   0.0
# 11              1.0              0.0               0.0                   0.0
# 12              1.0              5.0               2.0                   0.0
# 13              2.0              1.0              82.0                   0.0
# 14              1.0              2.0              25.0                   0.0
#
#     Score
# 0    3.68
# 1    3.23
# 2    3.23
# 3    3.57
# 4    4.13
# 5    3.31
# 6    4.17
# 7    3.38
# 8    3.06
# 9    4.17
# 10   3.25
# 11   3.58
# 12   3.90
# 13   4.50
# 14   4.05

# %%
rnr_df.to_csv("output/2019.csv")
