# %%
import pandas as pd
import numpy as np

# %%
hof_df = pd.read_csv("nominees_2019.csv")
hof_df.drop(hof_df.loc[hof_df["Years Waited"]=="*"].index, inplace=True)
hof_df.drop(columns=["Inducted By"], inplace=True)
hof_df.head()
# Out:
#             Artist  Year Inducted Years Waited # of Years Nominated
# 0         Bon Jovi           2018            9                    2
# 1         The Cars           2018           14                    3
# 2     Dire Straits           2018           14                    1
# 3  The Moody Blues           2018           28                    1
# 4      Nina Simone           2018           32                    1

# %%
infl_df = pd.read_csv("The 100 most influential artists, according to AllMusic data.csv")
infl_df = infl_df.rename(columns={"artistname" : "Artist", "artists influenced" : "Influenced"})
infl_df.head()
# Out:
#                  Artist  Influenced
# 0                  2Pac          39
# 1  A Tribe Called Quest          26
# 2                  ABBA          19
# 3                 AC/DC         121
# 4             Aerosmith          24

# %%
rnr_df = pd.merge(hof_df, infl_df, on="Artist", how="left")
rnr_df = rnr_df.sort_values(by=["Influenced"])
rnr_df.head()
# Out:
#                               Artist  Year Inducted Years Waited  \
# 41                      Darlene Love           2011           22
# 153  Frankie Lymon and the Teenagers           1993            7
# 94                     The Flamingos           2001           15
# 106                    The Moonglows           2000           14
# 117                      Lloyd Price           1998           12
#
#     # of Years Nominated  Influenced
# 41                     3         0.0
# 153                    8         0.0
# 94                     5         0.0
# 106                    6         0.0
# 117                    7         0.0

# %%
uss_df = pd.read_csv("Album sales US.csv")
rnr_df = pd.merge(rnr_df, uss_df, on="Artist", how="left")
rnr_df.head()
# Out:
#                             Artist  Year Inducted Years Waited  \
# 0                     Darlene Love           2011           22
# 1  Frankie Lymon and the Teenagers           1993            7
# 2                    The Flamingos           2001           15
# 3                    The Moonglows           2000           14
# 4                      Lloyd Price           1998           12
#
#   # of Years Nominated  Influenced  Certified Units (Millions)
# 0                    3         0.0                         0.0
# 1                    8         0.0                         0.0
# 2                    5         0.0                         0.0
# 3                    6         0.0                         0.0
# 4                    7         0.0                         0.0

# %%
rnr_df = rnr_df.sort_values(by=["Certified Units (Millions)"], ascending = False)
rsa_df = pd.read_csv("RS500.csv")
rnr_df = pd.merge(rnr_df, rsa_df, on="Artist", how="left")
rnr_df
# Out:
#                               Artist  Year Inducted Years Waited  \
# 0                        The Beatles           1988            0
# 1                      Elvis Presley           1986            0
# 2                         The Eagles           1998            0
# 3                       Led Zeppelin           1995            0
# 4                    Michael Jackson           2001            3
# 5                         Billy Joel           1999            2
# 6                         Elton John           1994            0
# 7                         Pink Floyd           1996            3
# 8                              AC/DC           2003            2
# 9                          Aerosmith           2001            2
# 10                The Rolling Stones           1989            0
# 11                 Bruce Springsteen           1999            0
# 12                           Madonna           2008            0
# 13                         Metallica           2009            1
# 14                         Van Halen           2007            3
# 15                     Fleetwood Mac           1998            4
# 16                                U2           2005            0
# 17                      Neil Diamond           2011           22
# 18                           Journey           2017           16
# 19                     Guns N' Roses           2012            0
# 20                         Bob Seger           2004           12
# 21                           Santana           1998            3
# 22                      Eric Clapton           2000            4
# 23                           Chicago           2016           21
# 24               Simon and Garfunkel           1990            0
# 25                       Rod Stewart           1994            4
# 209                    2        15.0                         NaN
# 210                    2        21.0                         NaN
# 211                    1       134.0                         NaN
# 212                    2       165.0                         NaN
# 213                    1       178.0                         NaN
#
#      Albums in RS500
# 0               10.0
# 1                3.0
# 2                2.0
# 3                5.0
# 4                3.0
# 5                2.0
# 6                5.0
# 7                4.0
# 8                2.0
# 9                2.0
# 10              10.0
# 11               8.0
# 12               3.0
# 13               2.0
# 14               1.0
# 15               2.0
# 16               5.0
# 17               1.0
# 18               NaN
# 19               1.0
# 20               NaN
# 21               2.0
# 22               3.0
# 23               NaN
# 24               3.0
# 25               1.0
# 26               4.0
# 27               NaN
# 28              11.0
# 29               1.0
# ..               ...
# 184              NaN
# 185              1.0
# 186              1.0
# 187              1.0
# 188              1.0
# 189              NaN
# 190              NaN
# 191              NaN
# 192              2.0
# 193              1.0
# 194              1.0
# 195              NaN
# 196              NaN
# 197              NaN
# 198              NaN
# 199              NaN
# 200              NaN
# 201              NaN
# 202              1.0
# 203              NaN
# 204              NaN
# 205              NaN
# 206              1.0
# 207              NaN
# 208              NaN
# 209              NaN
# 210              1.0
# 211              3.0
# 212              5.0
# 213              2.0
#
# [214 rows x 7 columns]

# %%
hot_df = pd.read_csv("hot100singles.csv")
hot_df = hot_df.rename(columns={"Row Labels" : "Artist"})
rnr_df = pd.merge(rnr_df, hot_df, on="Artist", how="left")
rnr_df.head()
# Out:
#             Artist  Year Inducted Years Waited # of Years Nominated  \
# 0      The Beatles           1988            0                    1
# 1    Elvis Presley           1986            0                    1
# 2       The Eagles           1998            0                    1
# 3     Led Zeppelin           1995            0                    1
# 4  Michael Jackson           2001            3                    1
#
#    Influenced  Certified Units (Millions)  Albums in RS500  Top 100 Singles  \
# 0      1230.0                       178.0             10.0             80.0
# 1       273.0                       146.5              3.0            158.0
# 2        17.0                       120.0              2.0             21.0
# 3       355.0                       111.5              5.0             10.0
# 4       176.0                        84.0              3.0             49.0
#
#    Highest Position
# 0               1.0
# 1               1.0
# 2               1.0
# 3               4.0
# 4               1.0

# %%
rsc_df = pd.read_csv("RSCovers.csv")
rnr_df = pd.merge(rnr_df, rsc_df, on="Artist", how="left")

# %%
abs_df = pd.read_csv("Album_scores.csv")
rnr_df = pd.merge(rnr_df, abs_df, on="Artist", how="left")
rnr_df.head()
# Out:
#             Artist  Year Inducted Years Waited # of Years Nominated  \
# 0      The Beatles           1988            0                    1
# 1    Elvis Presley           1986            0                    1
# 2       The Eagles           1998            0                    1
# 3     Led Zeppelin           1995            0                    1
# 4  Michael Jackson           2001            3                    1
#
#    Influenced  Certified Units (Millions)  Albums in RS500  Top 100 Singles  \
# 0      1230.0                       178.0             10.0             80.0
# 1       273.0                       146.5              3.0            158.0
# 2        17.0                       120.0              2.0             21.0
# 3       355.0                       111.5              5.0             10.0
# 4       176.0                        84.0              3.0             49.0
#
#    Highest Position  Times on Cover of RS  Score
# 0               1.0                  16.0   4.81
# 1               1.0                   7.0   3.31
# 2               1.0                   3.0   3.50
# 3               4.0                  12.0   4.50
# 4               1.0                   6.0   3.65

# %%
rnr_df.to_csv("output/2019.csv")
